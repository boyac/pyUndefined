# %%
import pandas
import time

dfs = pandas.read_html('http://rate.bot.com.tw/xrt?Lang=zh-TW')

# %%
dfs[0]
# Out:
#                         幣別     幣別.1     現金匯率 Unnamed: 3    即期匯率 Unnamed: 5  \
# 0       美金 (USD)  美金 (USD)    31.59   32.132      31.89   31.99         查詢
# 1       港幣 (HKD)  港幣 (HKD)    3.964    4.159      4.084   4.144         查詢
# 2       英鎊 (GBP)  英鎊 (GBP)    38.69    40.62      39.56   39.98         查詢
# 3       澳幣 (AUD)  澳幣 (AUD)    23.16    23.82      23.35   23.58         查詢
# 4   加拿大幣 (CAD)  加拿大幣 (CAD)    23.59    24.33      23.86   24.08         查詢
# 5   新加坡幣 (SGD)  新加坡幣 (SGD)    21.64    22.42      22.06   22.24         查詢
# 6   瑞士法郎 (CHF)  瑞士法郎 (CHF)    30.39    31.45      30.92   31.21         查詢
# 7       日圓 (JPY)  日圓 (JPY)   0.2621   0.2731     0.2685  0.2725         查詢
# 8     南非幣 (ZAR)  南非幣 (ZAR)        -        -       2.25    2.33         查詢
# 9     瑞典幣 (SEK)  瑞典幣 (SEK)     3.02     3.53       3.36    3.46         查詢
# 10      紐元 (NZD)  紐元 (NZD)    22.13    22.76      22.37   22.57         查詢
# 11      泰幣 (THB)  泰幣 (THB)   0.7894   0.9324     0.8779  0.9179         查詢
# 12  菲國比索 (PHP)  菲國比索 (PHP)   0.5908   0.7238          -       -         查詢
# 13    印尼幣 (IDR)  印尼幣 (IDR)  0.00208  0.00278          -       -         查詢
# 14      歐元 (EUR)  歐元 (EUR)    32.68    33.83      33.18   33.58         查詢
# 15      韓元 (KRW)  韓元 (KRW)  0.02524  0.02914          -       -         查詢
# 16    越南盾 (VND)  越南盾 (VND)  0.00103  0.00153          -       -         查詢
# 17    馬來幣 (MYR)  馬來幣 (MYR)     6.05     7.65          -       -         查詢
# 18    人民幣 (CNY)  人民幣 (CNY)    4.509    4.671      4.581   4.631         查詢
#
#    \n                    遠期匯率\n                     歷史匯率   歷史匯率.1  現金匯率.1  \
# 0                                            查詢    31.59   32.132   31.89
# 1                                            查詢    3.964    4.159   4.084
# 2                                            查詢    38.69    40.62   39.56
# 3                                            查詢    23.16    23.82   23.35
# 4                                            查詢    23.59    24.33   23.86
# 5                                            查詢    21.64    22.42   22.06
# 6                                            查詢    30.39    31.45   30.92
# 7                                            查詢   0.2621   0.2731  0.2685
# 8                                            查詢        -        -    2.25
# 9                                            查詢     3.02     3.53    3.36
# 10                                           查詢    22.13    22.76   22.37
# 11                                           查詢   0.7894   0.9324  0.8779
# 12                                           查詢   0.5908   0.7238       -
# 13                                           查詢  0.00208  0.00278       -
# 14                                           查詢    32.68    33.83   33.18
# 15                                           查詢  0.02524  0.02914       -
# 16                                           查詢  0.00103  0.00153       -
# 17                                           查詢     6.05     7.65       -
# 18                                           查詢    4.509    4.671   4.581
#
#      ...   Unnamed: 13  \
# 0    ...           NaN
# 1    ...           NaN
# 2    ...           NaN
# 3    ...           NaN
# 4    ...           NaN
# 5    ...           NaN
# 6    ...           NaN
# 7    ...           NaN
# 8    ...           NaN
# 9    ...           NaN
# 10   ...           NaN
# 11   ...           NaN
# 12   ...           NaN
# 13   ...           NaN
# 14   ...           NaN
# 15   ...           NaN
# 16   ...           NaN
# 17   ...           NaN
# 18   ...           NaN
#
#     \n                    \n                        本行買入\n                    \n                  \
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6                                                 NaN
# 7                                                 NaN
# 8                                                 NaN
# 9                                                 NaN
# 10                                                NaN
# 11                                                NaN
# 12                                                NaN
# 13                                                NaN
# 14                                                NaN
# 15                                                NaN
# 16                                                NaN
# 17                                                NaN
# 18                                                NaN
#
#     \n                    \n                        本行賣出\n                    \n                  \
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6                                                 NaN
# 7                                                 NaN
# 8                                                 NaN
# 9                                                 NaN
# 10                                                NaN
# 11                                                NaN
# 12                                                NaN
# 13                                                NaN
# 14                                                NaN
# 15                                                NaN
# 16                                                NaN
# 17                                                NaN
# 18                                                NaN
#
#     \n                    \n                        本行買入\n                    \n                .1  \
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6                                                 NaN
# 7                                                 NaN
# 8                                                 NaN
# 9                                                 NaN
# 10                                                NaN
# 11                                                NaN
# 12                                                NaN
# 13                                                NaN
# 14                                                NaN
# 15                                                NaN
# 16                                                NaN
# 17                                                NaN
# 18                                                NaN
#
#     \n                    \n                        本行賣出\n                    \n                .1  \
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6                                                 NaN
# 7                                                 NaN
# 8                                                 NaN
# 9                                                 NaN
# 10                                                NaN
# 11                                                NaN
# 12                                                NaN
# 13                                                NaN
# 14                                                NaN
# 15                                                NaN
# 16                                                NaN
# 17                                                NaN
# 18                                                NaN
#
#     Unnamed: 18  本行買入  本行賣出  本行買入.1  本行賣出.1
# 0           NaN   NaN   NaN     NaN     NaN
# 1           NaN   NaN   NaN     NaN     NaN
# 2           NaN   NaN   NaN     NaN     NaN
# 3           NaN   NaN   NaN     NaN     NaN
# 4           NaN   NaN   NaN     NaN     NaN
# 5           NaN   NaN   NaN     NaN     NaN
# 6           NaN   NaN   NaN     NaN     NaN
# 7           NaN   NaN   NaN     NaN     NaN
# 8           NaN   NaN   NaN     NaN     NaN
# 9           NaN   NaN   NaN     NaN     NaN
# 10          NaN   NaN   NaN     NaN     NaN
# 11          NaN   NaN   NaN     NaN     NaN
# 12          NaN   NaN   NaN     NaN     NaN
# 13          NaN   NaN   NaN     NaN     NaN
# 14          NaN   NaN   NaN     NaN     NaN
# 15          NaN   NaN   NaN     NaN     NaN
# 16          NaN   NaN   NaN     NaN     NaN
# 17          NaN   NaN   NaN     NaN     NaN
# 18          NaN   NaN   NaN     NaN     NaN
#
# [19 rows x 23 columns]

# %%
currency = dfs[0]

# %%
currency = currency.ix[:,0:5] #選取需要的[row,column]

# %%
currency.columns = [u'幣別', u'現金匯率-本行買入', u'現金匯率-本行賣出', u'即期匯率-本行買入', u'即期匯率-本行賣出'] #修改 header

# %%
currency[u'幣別'] = currency[u'幣別'].str.extract('\((\w+)\)')
# Out:
# /usr/local/lib/python2.7/site-packages/IPython/kernel/__main__.py:1: FutureWarning: currently extract(expand=None) means expand=False (return Index/Series/DataFrame) but in a future version of pandas this will be changed to expand=True (return DataFrame)
#   if __name__ == '__main__':

# %%
currency
# Out:
#      幣別 現金匯率-本行買入 現金匯率-本行賣出 即期匯率-本行買入 即期匯率-本行賣出
# 0   USD     31.59    32.132     31.89     31.99
# 1   HKD     3.964     4.159     4.084     4.144
# 2   GBP     38.69     40.62     39.56     39.98
# 3   AUD     23.16     23.82     23.35     23.58
# 4   CAD     23.59     24.33     23.86     24.08
# 5   SGD     21.64     22.42     22.06     22.24
# 6   CHF     30.39     31.45     30.92     31.21
# 7   JPY    0.2621    0.2731    0.2685    0.2725
# 8   ZAR         -         -      2.25      2.33
# 9   SEK      3.02      3.53      3.36      3.46
# 10  NZD     22.13     22.76     22.37     22.57
# 11  THB    0.7894    0.9324    0.8779    0.9179
# 12  PHP    0.5908    0.7238         -         -
# 13  IDR   0.00208   0.00278         -         -
# 14  EUR     32.68     33.83     33.18     33.58
# 15  KRW   0.02524   0.02914         -         -
# 16  VND   0.00103   0.00153         -         -
# 17  MYR      6.05      7.65         -         -
# 18  CNY     4.509     4.671     4.581     4.631

# %%
currency.to_excel('yen_rate.xlsx')
count = 1

while True:
    filename = 'yen_rate_' + str(count) + '.xlsx'
    currency.to_excel(filename)
    time.sleep(5*60)
    count += 1
